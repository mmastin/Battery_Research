# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# lowpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/lowpoint_full.csv')
# midpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/midpoint_full.csv')
# highpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/highpoint_full.csv')
# stretchpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/stretchpoint_full.csv')

lowpoint.shape, midpoint.shape, highpoint.shape, stretchpoint.shape
# Out:
# ((690, 14), (690, 14), (690, 14), (690, 14))

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
class StringConverter(dict):
    def __contains__(self, item):
        return True
    
    def __getitem__(self, item):
        return str
    
    def __get(self, default=None):
        return str

# %%
lowpoint.head()
# Out:
#                                                 Rate   Building Type  \
# 0  E-19_Medium_General_Demand_TOU_(Secondary_Volu...       Fast Food
# 1  Schedule_TOU-GSD-10_Time_Of_Use_-_General_Serv...      Outpatient
# 2             Power_and_Light_Medium_Schedule_PLM-11    Retail Store
# 3                              General_Service_(A14)  Primary School
# 4  A-10_Medium_General_Demand_Service_(Secondary_...     Supermarket
#
#             City  Cost Point Selector Battery Capacity (kWh)  \
# 0  San Francisco                    1                 65 kWh
# 1        Atlanta                    1                  0 kWh
# 2        Atlanta                    1                  0 kWh
# 3         Duluth                    1                  0 kWh
# 4  San Francisco                    1                903 kWh
#
#   Battery Power (kW)  BAU Demand Cost  BAU Energy Cost Capital Cost ($)  \
# 0              11 kW         87751.00        164109.00             $41K
# 1               0 kW        374541.00        900645.00             $36K
# 2               0 kW             0.00        235549.00              $0K
# 3               0 kW        300907.00        519891.00             $40K
# 4             125 kW        471299.00       2346650.00            $551K
#
#   Max Demand Rate ($/kW) Npv ($) PV Size (kW)  Total Demand Savings ($)  \
# 0                 $34.72     $0M        56 kW                  32045.80
# 1                 $15.66     $0M        74 kW                  15181.00
# 2                  $0.00     $0M         0 kW                      0.00
# 3                 $14.98     $0M        82 kW                  22187.00
# 4                 $16.78     $0M       770 kW                 225257.00
#
#    Total kWh Savings ($)
# 0               74991.00
# 1               49003.00
# 2                   0.00
# 3               54835.00
# 4             1325750.00

# %%
lowpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/lowpoint_full.csv', 
                       converters=StringConverter())
lowpoint.dtypes
# Out:
# Rate                        object
# Building Type               object
# City                        object
# Cost Point Selector         object
# Battery Capacity (kWh)      object
# Battery Power (kW)          object
# BAU Demand Cost             object
# BAU Energy Cost             object
# Capital Cost ($)            object
# Max Demand Rate ($/kW)      object
# Npv ($)                     object
# PV Size (kW)                object
# Total Demand Savings ($)    object
# Total kWh Savings ($)       object
# dtype: object

# %%
lowpoint = pd.read_csv('/Users/mattmastin/Desktop/Battery_Research/lowpoint_full.csv', 
                       converters=defaultdict(lambda i: str))
lowpoint.dtypes
# Out:
# Rate                         object
# Building Type                object
# City                         object
# Cost Point Selector           int64
# Battery Capacity (kWh)       object
# Battery Power (kW)           object
# BAU Demand Cost             float64
# BAU Energy Cost             float64
# Capital Cost ($)             object
# Max Demand Rate ($/kW)       object
# Npv ($)                      object
# PV Size (kW)                 object
# Total Demand Savings ($)    float64
# Total kWh Savings ($)       float64
# dtype: object

# %%
midpoint.head()
# Out:
#                                                 Rate Building Type  \
# 0      Primary_Service_A-2_Rate(B)_Time-Of-Use_(TOU)      Hospital
# 1  Schedule_MDE-_Medium_Standard_General_Service_...   Supermarket
# 2          BES-Large_Load_Delivery_Class_(Secondary)      Hospital
# 3      Primary_Service_A-2_Rate(B)_Time-Of-Use_(TOU)    Restaurant
# 4   General_Service_With_Demand_Meter_(Rate_Code_25)    Restaurant
#
#           City  Cost Point Selector Battery Capacity (kWh) Battery Power (kW)  \
# 0  Los Angeles                    1                263 kWh             119 kW
# 1      Seattle                    1                  0 kWh               0 kW
# 2      Chicago                    1                  0 kWh               0 kW
# 3  Los Angeles                    1                  9 kWh               4 kW
# 4  Minneapolis                    1                  0 kWh               0 kW
#
#    BAU Demand Cost  BAU Energy Cost Capital Cost ($) Max Demand Rate ($/kW)  \
# 0       2284920.00       7236560.00          $1,291K                 $17.48
# 1         84094.80       1194410.00              $0K                  $2.32
# 2       1025220.00       5216790.00              $0K                  $6.73
# 3         97555.10        298486.00             $48K                 $17.48
# 4         34934.70        237610.00             $28K                  $5.86
#
#   Npv ($) PV Size (kW)  Total Demand Savings ($)  Total kWh Savings ($)
# 0     $1M     2,114 kW                 513700.00             2731480.00
# 1     $0M         0 kW                      0.00                   0.00
# 2     $0M         0 kW                      0.00                   0.00
# 3     $0M        80 kW                  22243.20              105042.00
# 4     $0M        50 kW                   1039.00               47135.00

# %%
highpoint.head()
# Out:
#                                                 Rate   Building Type  \
# 0  E-32_STANDARD_PRICE_PLAN_FOR_TIME-OF-USE_GENER...    Large Office
# 1                              General_Service_(A14)  Primary School
# 2  E-19_Medium_General_Demand_TOU_(Secondary_Volu...      Restaurant
# 3  E-32_STANDARD_PRICE_PLAN_FOR_TIME-OF-USE_GENER...     Small Hotel
# 4           GS-2_(S)_Large_General_Service_Secondary       Fast Food
#
#             City  Cost Point Selector Battery Capacity (kWh)  \
# 0        Phoenix                    1                  0 kWh
# 1         Duluth                    1                  0 kWh
# 2  San Francisco                    1                 17 kWh
# 3        Phoenix                    1                  0 kWh
# 4      Fairbanks                    1                  0 kWh
#
#   Battery Power (kW)  BAU Demand Cost  BAU Energy Cost Capital Cost ($)  \
# 0               0 kW       1064400.00       5036200.00            $457K
# 1               0 kW        300907.00        519891.00              $1K
# 2               7 kW        155419.00        283560.00             $54K
# 3               0 kW        106889.00        589592.00              $0K
# 4               0 kW         32908.50        293718.00             $28K
#
#   Max Demand Rate ($/kW) Npv ($) PV Size (kW)  Total Demand Savings ($)  \
# 0                  $6.65     $0M       674 kW                  97372.00
# 1                 $14.98     $0M         2 kW                    876.00
# 2                 $34.72     $0M        67 kW                  31314.00
# 3                  $6.65     $0M         0 kW                      0.00
# 4                 $11.06     $0M        41 kW                   1147.70
#
#    Total kWh Savings ($)
# 0              709300.00
# 1                1235.00
# 2               95538.00
# 3                   0.00
# 4               61013.00

# %%
stretchpoint.head()
# Out:
#                                                 Rate Building Type  \
# 0  LGS-2_Large_General_Service-_Secondary_Distrib...   Large Hotel
# 1                           2A_(Small_Power_Service)  Small Office
# 2         BES-Medium_Load_Delivery_Class_(Secondary)      Hospital
# 3             Power_and_Light_Medium_Schedule_PLM-11     Fast Food
# 4  Time-Of-Use_-_General_Service_-_Large_TOU-8_Op...   Large Hotel
#
#           City  Cost Point Selector Battery Capacity (kWh) Battery Power (kW)  \
# 0     LasVegas                    1                  0 kWh               0 kW
# 1  Albuquerque                    1                  0 kWh               0 kW
# 2      Chicago                    1                  0 kWh               0 kW
# 3      Atlanta                    1                  0 kWh               0 kW
# 4      Anaheim                    1              1,307 kWh             204 kW
#
#    BAU Demand Cost  BAU Energy Cost Capital Cost ($) Max Demand Rate ($/kW)  \
# 0        547920.00       1362130.00            $142K                 $16.49
# 1             0.00         89940.70             $14K                  $0.00
# 2        958188.00       5216790.00            $574K                  $6.29
# 3             0.00         85605.10              $0K                  $0.00
# 4        787000.00       2151870.00            $549K                 $15.57
#
#   Npv ($) PV Size (kW)  Total Demand Savings ($)  Total kWh Savings ($)
# 0     $0M       320 kW                    904.00              265840.00
# 1     $0M        30 kW                      0.00               39972.40
# 2     $0M     1,287 kW                  50744.00              965060.00
# 3     $0M         0 kW                      0.00                   0.00
# 4     $0M       777 kW                 318052.00             1189796.00

# %%
low = lowpoint.copy()
mid = midpoint.copy()
high = highpoint.copy()
stretch = stretchpoint.copy()

low['Battery Capacity (kWh)'] = low['Battery Capacity (kWh)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
low['Battery Power (kW)'] = low['Battery Power (kW)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
low['Capital Cost ($)'] = low['Capital Cost ($)'].str.slice(1, -1, 1
                                                            ).str.replace(',', '').astype(int) * 1000
low['Max Demand Rate ($/kW)'] = low['Max Demand Rate ($/kW)'].str.slice(1, 5, 1).astype(float)
low['Npv ($)'] = low['Npv ($)'].str.slice(1, 2, 1).astype(int) * 1000000
low['PV Size (kW)'] = low['PV Size (kW)'].str.slice(0, -2, 1).str.replace(',', '').astype(int)


mid['Battery Capacity (kWh)'] = mid['Battery Capacity (kWh)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
mid['Battery Power (kW)'] = mid['Battery Power (kW)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
mid['Capital Cost ($)'] = mid['Capital Cost ($)'].str.slice(1, -1, 1
                                                            ).str.replace(',', '').astype(int) * 1000
mid['Max Demand Rate ($/kW)'] = mid['Max Demand Rate ($/kW)'].str.slice(1, 5, 1).astype(float)
mid['Npv ($)'] = mid['Npv ($)'].str.slice(1, 2, 1).astype(int) * 1000000
mid['PV Size (kW)'] = mid['PV Size (kW)'].str.slice(0, -2, 1).str.replace(',', '').astype(int)


high['Battery Capacity (kWh)'] = high['Battery Capacity (kWh)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
high['Battery Power (kW)'] = high['Battery Power (kW)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
high['Capital Cost ($)'] = high['Capital Cost ($)'].str.slice(1, -1, 1
                                                            ).str.replace(',', '').astype(int) * 1000
high['Max Demand Rate ($/kW)'] = high['Max Demand Rate ($/kW)'].str.slice(1, 5, 1).astype(float)
high['Npv ($)'] = high['Npv ($)'].str.slice(1, 2, 1).astype(int) * 1000000
high['PV Size (kW)'] = high['PV Size (kW)'].str.slice(0, -2, 1).str.replace(',', '').astype(int)


stretch['Battery Capacity (kWh)'] = stretch['Battery Capacity (kWh)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
stretch['Battery Power (kW)'] = stretch['Battery Power (kW)'].str.slice(0, -3, 1
                                                            ).str.replace(',', '').astype(int)
stretch['Capital Cost ($)'] = stretch['Capital Cost ($)'].str.slice(1, -1, 1
                                                            ).str.replace(',', '').astype(int) * 1000
stretch['Max Demand Rate ($/kW)'] = stretch['Max Demand Rate ($/kW)'].str.slice(1, 5, 1).astype(float)
stretch['Npv ($)'] = stretch['Npv ($)'].str.slice(1, 2, 1).astype(int) * 1000000
stretch['PV Size (kW)'] = stretch['PV Size (kW)'].str.slice(0, -2, 1).str.replace(',', '').astype(int)

# %%
midpoint.isna().sum()
# Out:
# Rate                        0
# Building Type               0
# City                        0
# Cost Point Selector         0
# Battery Capacity (kWh)      0
# Battery Power (kW)          0
# BAU Demand Cost             0
# BAU Energy Cost             0
# Capital Cost ($)            0
# Max Demand Rate ($/kW)      0
# Npv ($)                     0
# PV Size (kW)                0
# Total Demand Savings ($)    0
# Total kWh Savings ($)       0
# dtype: int64

# %%
low.drop(columns=['Cost Point Selector'])
mid.drop(columns=['Cost Point Selector'])
high.drop(columns=['Cost Point Selector'])
stretch.drop(columns=['Cost Point Selector']);

# %%
mid.head()
# Out:
#                                                 Rate Building Type  \
# 0      Primary_Service_A-2_Rate(B)_Time-Of-Use_(TOU)      Hospital
# 1  Schedule_MDE-_Medium_Standard_General_Service_...   Supermarket
# 2          BES-Large_Load_Delivery_Class_(Secondary)      Hospital
# 3      Primary_Service_A-2_Rate(B)_Time-Of-Use_(TOU)    Restaurant
# 4   General_Service_With_Demand_Meter_(Rate_Code_25)    Restaurant
#
#           City  Cost Point Selector  Battery Capacity (kWh)  \
# 0  Los Angeles                    1                     263
# 1      Seattle                    1                       0
# 2      Chicago                    1                       0
# 3  Los Angeles                    1                       9
# 4  Minneapolis                    1                       0
#
#    Battery Power (kW)  BAU Demand Cost  BAU Energy Cost  Capital Cost ($)  \
# 0                 119       2284920.00       7236560.00           1291000
# 1                   0         84094.80       1194410.00                 0
# 2                   0       1025220.00       5216790.00                 0
# 3                   4         97555.10        298486.00             48000
# 4                   0         34934.70        237610.00             28000
#
#    Max Demand Rate ($/kW)  Npv ($)  PV Size (kW)  Total Demand Savings ($)  \
# 0                   17.40  1000000          2114                 513700.00
# 1                    2.32        0             0                      0.00
# 2                    6.73        0             0                      0.00
# 3                   17.40        0            80                  22243.20
# 4                    5.86        0            50                   1039.00
#
#    Total kWh Savings ($)
# 0             2731480.00
# 1                   0.00
# 2                   0.00
# 3              105042.00
# 4               47135.00

# %%
mid.describe()
# Out:
#        Cost Point Selector  Battery Capacity (kWh)  BAU Demand Cost  \
# count               690.00                  690.00           690.00
# mean                  1.00                   49.74        317187.51
# std                   0.00                  210.51        674986.57
# min                   1.00                    0.00             0.00
# 25%                   1.00                    0.00         12223.70
# 50%                   1.00                    0.00         84094.80
# 75%                   1.00                    9.75        334127.50
# max                   1.00                 2765.00       7658200.00
#
#        BAU Energy Cost  Total Demand Savings ($)  Total kWh Savings ($)
# count           690.00                    690.00                 690.00
# mean        1250769.90                  56055.60              312400.51
# std         1805570.50                 196787.72              749083.49
# min           27280.00                      0.00                  -3.00
# 25%          232032.75                      0.00                  22.12
# 50%          582058.00                   1272.25               75813.50
# 75%         1406270.00                  29376.18              299106.50
# max        16224000.00                2972380.00             9631510.00
